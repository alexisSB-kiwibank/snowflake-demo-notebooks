# %% [markdown]
# # Snowflake Notebook POC
#
# Playing around with Snowflake Notebooks to explore features and usability.
#
# Target question: How many characters from Titanic the movie have the same name as passengers or crew from the actual ship?
# Extension: Were they more or less likely to survive if they were in the movie?

# %% [markdown]
# ## Load Details about Current Session

# %%
import streamlit as st
from snowflake.snowpark.context import get_active_session
session = get_active_session()
current_user = session.get_current_user().strip('"')
current_database = session.get_current_database()
print('Your current CONTEXT information:')
print('---------------------------------')
print(session)
print('Your current USER is ' + user)
print('Your current DATABASE is')

# %% [markdown]
# ## Setup the Data Stage and Upload Data
#
# There are three sets of data that I need to upload
# 1. A csv file listing all of the actors in Titanic and the role that they played
# 2. A csv file listing information about all of the passengers on the titanic
# 3. A pdf file listing all of the crew members on the titanic.
#
# First I need to create a stage to upload them to

# %%
CREATE STAGE IF NOT EXISTS 
    IDENTIFIER('"ALEXIS_NOTEBOOK_POC_DB"."STAGES"."TITANIC"') 
    DIRECTORY = ( ENABLE = true ) 
    ENCRYPTION = ( TYPE = 'SNOWFLAKE_SSE' )  ;

# %%
# Import python packages
import streamlit as st
import pandas as pd

# We can also use Snowpark for our analyses!
from snowflake.snowpark.context import get_active_session
session = get_active_session()

# %%
-- Welcome to Snowflake Notebooks!
-- Try out a SQL cell to generate some data.
SELECT 'FRIDAY' as SNOWDAY, 0.2 as CHANCE_OF_SNOW
UNION ALL
SELECT 'SATURDAY',0.5
UNION ALL 
SELECT 'SUNDAY', 0.9;

# %%
# Then, we can use the python name to turn cell2 into a Pandas dataframe
my_df = cell2.to_pandas()

# Chart the data
st.subheader("Chance of SNOW ❄️")
st.line_chart(my_df, x='SNOWDAY', y='CHANCE_OF_SNOW')

# Give it a go!
st.subheader("Try it out yourself and show off your skills 🥇")
